# %% [markdown]
# # 19 — Quantum Kernels
#
# **Concept.** Feature maps embed data; kernel is state fidelity.

# %%
import os, sys
_LQE = os.environ.get("LQE_PATH", os.path.abspath(os.path.join("..", "Legitimate-Quantum-Engine")))
if _LQE not in sys.path: sys.path.insert(0, _LQE)
from legitimate_quantum_engine.utils.quantum_kernel import kernel_matrix
import numpy as np

X = np.array([[0.1,0.2,0,0],[0.15,0.25,0,0],[0.8,0.7,0,0],[0.85,0.75,0,0]])
K = kernel_matrix(X, n_qubits=2, reps=1)
print(np.round(K, 4))

# %% [markdown]
# **Takeaway.** Quantum kernels turn overlaps into classical ML kernels.
